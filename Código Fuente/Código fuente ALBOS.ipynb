área  Código Elemento    Elemento  Código Producto (FAO)  \
# ...

# %%
Guatemala = data[data.Área=="Guatemala"]

# %%
Guatemala
# Out:
#     Código Ámbito                             Ámbito  Código área (M49)  \
# 692           QCL  Cultivos y productos de ganadería                320
# 693           QCL  Cultivos y productos de ganadería                320
# 694           QCL  Cultivos y productos de ganadería                320
# 695           QCL  Cultivos y productos de ganadería                320
# 696           QCL  Cultivos y productos de ganadería                320
# 697           QCL  Cultivos y productos de ganadería                320
# 698           QCL  Cultivos y productos de ganadería                320
# 699           QCL  Cultivos y productos de ganadería                320
# 700           QCL  Cultivos y productos de ganadería                320
# 701           QCL  Cultivos y productos de ganadería                320
# 702           QCL  Cultivos y productos de ganadería                320
#
#           Área  Código Elemento    Elemento  Código Producto (FAO)  \
# ...

# %%
Belice = data[data.Área=="Belice"]

# %%
Belice
# Out:
#     Código Ámbito                             Ámbito  Código área (M49)  \
# 145           QCL  Cultivos y productos de ganadería                 84
# 146           QCL  Cultivos y productos de ganadería                 84
# 147           QCL  Cultivos y productos de ganadería                 84
# 148           QCL  Cultivos y productos de ganadería                 84
# 149           QCL  Cultivos y productos de ganadería                 84
# 150           QCL  Cultivos y productos de ganadería                 84
# 151           QCL  Cultivos y productos de ganadería                 84
# 152           QCL  Cultivos y productos de ganadería                 84
# 153           QCL  Cultivos y productos de ganadería                 84
# 154           QCL  Cultivos y productos de ganadería                 84
# 155           QCL  Cultivos y productos de ganadería                 84
#
#        Área  Código Elemento    Elemento  Código Producto (FAO)  \
# ...

# %%
plt.plot(Panamá.Año, Panamá.Valor)
plt.plot(CR.Año, CR.Valor)
plt.plot(Nicaragua.Año, Nicaragua.Valor)
plt.plot(Honduras.Año, Honduras.Valor)
plt.plot(Es.Año, Es.Valor)
plt.plot(Guatemala.Año, Guatemala.Valor)
plt.plot(Belice.Año, Belice.Valor)
plt.legend(["Panamá", "CR", "Nicaragua", "Honduras", "Es", "Guatemala", "Belice",])
plt.xlabel("Año")
plt.ylabel("Valor")
plt.show()

# %%
Guatemala.Valor
# Out:
# 692    5031
# 693    5143
# 694    5271
# 695    5271
# 696    5345
# 697    5399
# 698    5324
# 699    5345
# 700    5451
# 701    5507
# 702    5557
# Name: Valor, dtype: int64

# %%
Belice.Valor
# Out:
# 145     71
# 146     68
# 147     81
# 148     78
# 149     79
# 150     95
# 151     98
# 152    103
# 153    123
# 154    119
# 155    119
# Name: Valor, dtype: int64

# %%
plt.plot(USA.Año, USA.Valor)
plt.plot(China.Año, China.Valor)
plt.legend(["Estados Unidos de América", "China",])
plt.xlabel("Año")
plt.ylabel("Valor")
plt.show()

# %%
USA.Valor
# Out:
# 539    674262
# 540    683864
# 541    698658
# 542    696695
# 543    686347
# 544    736162
# 545    749364
# 546    768614
# 547    790591
# 548    830302
# 549    850309
# Name: Valor, dtype: int64

# %%
China.Valor
# Out:
# 337    2302986
# 338    2298693
# 339    2424346
# 340    2488934
# 341    2564609
# 342    2554147
# 343    2456653
# 344    2467205
# 345    2447275
# 346    1941297
# 347    1880541
# Name: Valor, dtype: int64
